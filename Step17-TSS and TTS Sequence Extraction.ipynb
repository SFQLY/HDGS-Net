# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-NNFR-1N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-NNFR-1N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-NNFR-2N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-NNFR-2N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-NNFR-3N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-NNFR-3N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-NNFR+1N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-NNFR+1N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-NNFR+2N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-NNFR+2N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-NNFR+3N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-NNFR+3N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+NNFR-1N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+NNFR-1N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+NNFR-2N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+NNFR-2N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+NNFR-3N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+NNFR-3N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+NNFR+1N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+NNFR+1N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+NNFR+2N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+NNFR+2N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+NNFR+3N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+NNFR+3N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-SNFR-1N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-SNFR-1N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-SNFR-2N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-SNFR-2N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-SNFR-3N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-SNFR-3N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-SNFR+1N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-SNFR+1N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-SNFR+2N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-SNFR+2N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/-SNFR+3N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_-SNFR+3N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+SNFR-1N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+SNFR-1N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+SNFR-2N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+SNFR-2N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+SNFR-3N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+SNFR-3N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+SNFR+1N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+SNFR+1N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+SNFR+2N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+SNFR+2N-ALL.txt' 
process_sequences(input_file, output_file)

# %%
def process_sequences(input_file, output_file):
    with open(input_file, 'r') as infile, open(output_file, 'w') as outfile:
        for line_number, line in enumerate(infile, 1): 
            sequence = line.strip()  
            if not sequence:
                continue   
            if len(sequence) != 203:
                print(f"Warning: 第{line_number}行序列长度不是203bp，已跳过该序列: {sequence}")
                continue
            center_index = len(sequence) // 2  
            new_sequence = sequence[center_index - 73 : center_index + 74]
            if len(new_sequence) != 147:
                print(f"Error: 第{line_number}行截取序列长度错误，原序列: {sequence}")
                continue
            outfile.write(new_sequence + '\n')
input_file = 'TSS-TTS序列/+SNFR+3N-ALL.txt' 
output_file = 'TSS-TTS处理序列/processed_+SNFR+3N-ALL.txt' 
process_sequences(input_file, output_file)
